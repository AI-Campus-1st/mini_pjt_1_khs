# %%
import pandas as pd

# %%
base_df = pd.read_csv('../data/상권정보_경기_202606.csv', encoding='utf-8')

# %%
base_df.head(10).T
# Out:
#                                    0                          1  \
# 상가업소번호          MA0106202201A0208596       MA0106202201A1978539
# 상호명                     파리바게트동탄2기시범점                       비비큐서
# 지점명                              NaN                        판교점
# 상권업종대분류코드                         I2                         I2
# 상권업종대분류명                          음식                         음식
# 상권업종중분류코드                       I210                       I201
# 상권업종중분류명                       기타 간이                         한식
# 상권업종소분류코드                     I21001                     I20101
# 상권업종소분류명                        빵/도넛                     백반/한정식
# 표준산업분류코드                      I56191                     I56111
# 표준산업분류명                         제과점업                 한식 일반 음식점업
# 시도코드                              41                         41
# 시도명                              경기도                        경기도
# 시군구코드                          41597                      41135
# 시군구명                         화성시 동탄구                    성남시 분당구
# 행정동코드                       41597540                   41135650
# 행정동명                            동탄4동                        판교동
# 법정동코드                     4159710500                 4113510800
# 법정동명                             청계동                        판교동
# 지번코드             4159710500105140002        4113510800104970000
# 대지구분코드                             1                          1
# 대지구분명                             대지                         대지
# 지번본번지                          514.0                      497.0
# 지번부번지                            2.0                        NaN
# 지번주소           경기도 화성시 동탄구 청계동 514-2        경기도 성남시 분당구 판교동 497
# 도로명코드                   415974852353               411353180044
# 도로명              경기도 화성시 동탄구 동탄대로시범길           경기도 성남시 분당구 서판교로
# 건물본번지                            253                        160
# 건물부번지                            NaN                        NaN
# 건물관리번호     4159013000200010000000002  4113510800104970000000001
# 건물명                              NaN                        NaN
# 도로명주소        경기도 화성시 동탄구 동탄대로시범길 253       경기도 성남시 분당구 서판교로 160
# 구우편번호                       445140.0                   463410.0
# 신우편번호                          18477                      13473
# 동정보                              NaN                        NaN
# 층정보                              NaN                        NaN
# 호정보                              NaN                        NaN
# 경도                        127.102754                 127.094801
# 위도                         37.202218                  37.400255
#
#                                    2                          3  \
# 상가업소번호          MA0106202201A0844862       MA0106202201A0604627
# 상호명                       비케이푸드/우미참치                      할리스커피
# 지점명                              NaN                       수원역점
# 상권업종대분류코드                         I2                         I2
# 상권업종대분류명                          음식                         음식
# 상권업종중분류코드                       I203                       I212
# 상권업종중분류명                          일식                      비알코올
# 상권업종소분류코드                     I20301                     I21201
# 상권업종소분류명                     일식 회/초밥                         카페
# 표준산업분류코드                      I56111                     I56221
# 표준산업분류명                   한식 일반 음식점업                     커피 전문점
# 시도코드                              41                         41
# 시도명                              경기도                        경기도
# 시군구코드                          41310                      41115
# 시군구명                             구리시                    수원시 팔달구
# 행정동코드                       41310520                   41115660
# 행정동명                             동구동                        매산동
# 법정동코드                     4131010300                 4111513400
# 법정동명                             인창동                      매산로1가
# 지번코드             4131010300104120042        4111513400100490018
# 대지구분코드                             1                          1
# 대지구분명                             대지                         대지
# 지번본번지                          412.0                       49.0
# 지번부번지                           42.0                       18.0
# 지번주소              경기도 구리시 인창동 412-42    경기도 수원시 팔달구 매산로1가 49-18
# 도로명코드                   413104388005               411153176018
# 도로명                 경기도 구리시 건원대로99번길            경기도 수원시 팔달구 향교로
# 건물본번지                              3                          6
# 건물부번지                            NaN                        NaN
# 건물관리번호     4131010300104120042001777  4111513400100490018049986
# 건물명                              NaN                        NaN
# 도로명주소             경기도 구리시 건원대로99번길 3          경기도 수원시 팔달구 향교로 6
# 구우편번호                       471833.0                   442081.0
# 신우편번호                          11918                      16455
# 동정보                              NaN                        NaN
# 층정보                              NaN                        NaN
# 호정보                              NaN                        NaN
# 경도                        127.137922                 127.001804
# 위도                         37.609606                  37.267526
#
#                                    4                          5  \
# 상가업소번호          MA0106202201A0624506       MA0106202201A1458077
# 상호명                           아트박스용인                  로라애슐리코리아덕
# 지점명                              중앙점                       평리지점
# 상권업종대분류코드                         G2                         G2
# 상권업종대분류명                          소매                         소매
# 상권업종중분류코드                       G213                       G209
# 상권업종중분류명                     오락용품 소매                섬유·의복·신발 소매
# 상권업종소분류코드                     G21302                     G20906
# 상권업종소분류명                 문구/회화용품 소매업                 침구류/커튼 소매업
# 표준산업분류코드                      G47612                     G47421
# 표준산업분류명              문구용품 및 회화용품 소매업               가정용 직물제품 소매업
# 시도코드                              41                         41
# 시도명                              경기도                        경기도
# 시군구코드                          41461                      41500
# 시군구명                         용인시 처인구                        이천시
# 행정동코드                       41461510                   41500340
# 행정동명                             중앙동                        마장면
# 법정동코드                     4146110100                 4150034031
# 법정동명                            김량장동                        마장면
# 지번코드             4146110100103010003        4150034031102930078
# 대지구분코드                             1                          1
# 대지구분명                             대지                         대지
# 지번본번지                          301.0                      293.0
# 지번부번지                            3.0                       78.0
# 지번주소          경기도 용인시 처인구 김량장동 301-3     경기도 이천시 마장면 이평리 293-78
# 도로명코드                   414613203017               415003203146
# 도로명                  경기도 용인시 처인구 금령로            경기도 이천시 마장면 덕평로
# 건물본번지                             86                        733
# 건물부번지                            NaN                       20.0
# 건물관리번호     4146110100103010003010526  4150034031102930078002932
# 건물명                              NaN                        NaN
# 도로명주소             경기도 용인시 처인구 금령로 86     경기도 이천시 마장면 덕평로 733-20
# 구우편번호                       449925.0                   467812.0
# 신우편번호                          17051                      17389
# 동정보                              NaN                        NaN
# 층정보                              NaN                        NaN
# 호정보                              NaN                        NaN
# 경도                        127.205822                 127.365234
# 위도                         37.235089                  37.225244
#
#                                    6                          7  \
# 상가업소번호          MA0106202201A0152042       MA0106202201A0035366
# 상호명                     에렉스후와후와스시앤누들          좋은사람들메가스토어남양주해피몰점
# 지점명                              NaN                        NaN
# 상권업종대분류코드                         I2                         G2
# 상권업종대분류명                          음식                         소매
# 상권업종중분류코드                       I203                       G209
# 상권업종중분류명                          일식                섬유·의복·신발 소매
# 상권업종소분류코드                     I20301                     G20905
# 상권업종소분류명                     일식 회/초밥                  기타 의류 소매업
# 표준산업분류코드                      I56122                     G47413
# 표준산업분류명                      일식 음식점업                속옷 및 잠옷 소매업
# 시도코드                              41                         41
# 시도명                              경기도                        경기도
# 시군구코드                          41135                      41360
# 시군구명                         성남시 분당구                       남양주시
# 행정동코드                       41135580                   41360540
# 행정동명                            서현1동                        양정동
# 법정동코드                     4113510500                 4136010600
# 법정동명                             서현동                        삼패동
# 지번코드             4113510500102480002        4136010600103510001
# 대지구분코드                             1                          1
# 대지구분명                             대지                         대지
# 지번본번지                          248.0                      351.0
# 지번부번지                            2.0                        1.0
# 지번주소           경기도 성남시 분당구 서현동 248-2         경기도 남양주시 삼패동 351-1
# 도로명코드                   411354340225               413603197071
# 도로명             경기도 성남시 분당구 서현로210번길               경기도 남양주시 고산로
# 건물본번지                             10                        280
# 건물부번지                            NaN                        NaN
# 건물관리번호     4113510500102480002001718  4136010600103510001000001
# 건물명                              NaN                        NaN
# 도로명주소        경기도 성남시 분당구 서현로210번길 10           경기도 남양주시 고산로 280
# 구우편번호                       463824.0                   472929.0
# 신우편번호                          13591                      12245
# 동정보                              NaN                        NaN
# 층정보                              NaN                        NaN
# 호정보                              NaN                        NaN
# 경도                         127.12482                 127.197145
# 위도                         37.386396                  37.592925
#
#                                    8                          9
# 상가업소번호          MA0106202201A0361901       MA0106202201A2114089
# 상호명                               지앤                       표준반상
# 지점명                              NaN                        NaN
# 상권업종대분류코드                         G2                         I2
# 상권업종대분류명                          소매                         음식
# 상권업종중분류코드                       G218                       I201
# 상권업종중분류명                      장식품 소매                         한식
# 상권업종소분류코드                     G21802                     I20101
# 상권업종소분류명                        기념품점                     백반/한정식
# 표준산업분류코드                      G47842                     I56111
# 표준산업분류명       기념품; 관광 민예품 및 장식용품 소매업                 한식 일반 음식점업
# 시도코드                              41                         41
# 시도명                              경기도                        경기도
# 시군구코드                          41463                      41450
# 시군구명                         용인시 기흥구                        하남시
# 행정동코드                       41463530                   41450610
# 행정동명                             상갈동                       미사1동
# 법정동코드                     4146310300                 4145010900
# 법정동명                             상갈동                        망월동
# 지번코드             4146310300101500007        4145010900112020001
# 대지구분코드                             1                          1
# 대지구분명                             대지                         대지
# 지번본번지                          150.0                     1202.0
# 지번부번지                            7.0                        1.0
# 지번주소           경기도 용인시 기흥구 상갈동 150-7         경기도 하남시 망월동 1202-1
# 도로명코드                   414633204031               414503202055
# 도로명                 경기도 용인시 기흥구 백남준로            경기도 하남시 미사강변한강로
# 건물본번지                              7                        350
# 건물부번지                            NaN                        NaN
# 건물관리번호     4146310300101500002002059  4145010900112020001000001
# 건물명                              NaN                        NaN
# 도로명주소             경기도 용인시 기흥구 백남준로 7        경기도 하남시 미사강변한강로 350
# 구우편번호                       446905.0                   465150.0
# 신우편번호                          17068                      12923
# 동정보                              NaN                        NaN
# 층정보                              NaN                        NaN
# 호정보                              NaN                        NaN
# 경도                        127.110118                 127.201653
# 위도                         37.269916                  37.559978

# %%
base_df.isnull().mean() * 100 #결측비율 확인
# Out:
# 상가업소번호         0.000000
# 상호명            0.000000
# 지점명           89.891776
# 상권업종대분류코드      0.000000
# 상권업종대분류명       0.000000
# 상권업종중분류코드      0.000000
# 상권업종중분류명       0.000000
# 상권업종소분류코드      0.000000
# 상권업종소분류명       0.000000
# 표준산업분류코드       0.032259
# 표준산업분류명        0.032259
# 시도코드           0.000000
# 시도명            0.000000
# 시군구코드          0.000000
# 시군구명           0.000000
# 행정동코드          0.000000
# 행정동명           0.000000
# 법정동코드          0.000000
# 법정동명           0.280668
# 지번코드           0.000000
# 대지구분코드         0.000000
# 대지구분명          0.000000
# 지번본번지          0.141077
# 지번부번지         26.251561
# 지번주소           0.000000
# 도로명코드          0.000000
# 도로명            0.000000
# 건물본번지          0.000000
# 건물부번지         80.005352
# 건물관리번호         0.558810
# 건물명           51.502943
# 도로명주소          0.000000
# 구우편번호          2.934828
# 신우편번호          0.000000
# 동정보          100.000000
# 층정보           49.629244
# 호정보          100.000000
# 경도             0.000000
# 위도             0.000000
# dtype: float64

# %%
base_df.describe()
# Out:
#            시도코드          시군구코드         행정동코드         법정동코드          지번코드  \
# count  672680.0  672680.000000  6.726800e+05  6.726800e+05  6.726800e+05
# mean       41.0   41354.648683  4.135517e+07  4.135479e+09  4.129653e+18
# std         0.0     184.645205  1.845804e+05  1.846805e+07  1.562990e+17
# min        41.0   41111.000000  4.111156e+07  4.111113e+09  4.111314e+14
# 25%        41.0   41192.000000  4.119264e+07  4.119211e+09  4.119211e+18
# 50%        41.0   41310.000000  4.131057e+07  4.131010e+09  4.131011e+18
# 75%        41.0   41480.000000  4.148055e+07  4.148012e+09  4.148012e+18
# max        41.0   41830.000000  4.183041e+07  4.183041e+09  4.183041e+18
#
#               대지구분코드          지번본번지          지번부번지         도로명코드  \
# count  672680.000000  671731.000000  496091.000000  6.726800e+05
# mean        1.001815     769.324064      13.409626  4.135501e+11
# std         0.042566     967.714936      45.697748  1.846467e+09
# min         1.000000       1.000000       1.000000  4.111120e+11
# 25%         1.000000     262.000000       2.000000  4.119244e+11
# 50%         1.000000     573.000000       5.000000  4.131044e+11
# 75%         1.000000     931.000000      10.000000  4.148034e+11
# max         2.000000    7346.000000    1443.000000  4.183049e+11
#
#                건물본번지          건물부번지          구우편번호          신우편번호  동정보  호정보  \
# count  672680.000000  134500.000000  652938.000000  672680.000000  0.0  0.0
# mean      202.395374      14.975450  444895.061180   14302.670344  NaN  NaN
# std       411.123775      22.171519   22032.667158    2624.489178  NaN  NaN
# min         1.000000       1.000000  410050.000000   10000.000000  NaN  NaN
# 25%        20.000000       2.000000  425842.000000   12054.000000  NaN  NaN
# 50%        57.000000       8.000000  445360.000000   14303.000000  NaN  NaN
# 75%       190.000000      19.000000  463839.000000   16668.000000  NaN  NaN
# max      8908.000000     601.000000  487936.000000   18635.000000  NaN  NaN
#
#                   경도             위도
# count  672680.000000  672680.000000
# mean      127.010904      37.432911
# std         0.203198       0.223298
# min       126.391044      36.903466
# 25%       126.833359      37.277139
# 50%       127.038403      37.397616
# 75%       127.129318      37.629945
# max       127.807489      38.230568

# %%
base_df.nunique()
# Out:
# 상가업소번호       672680
# 상호명          512939
# 지점명            1540
# 상권업종대분류코드        10
# 상권업종대분류명         10
# 상권업종중분류코드        75
# 상권업종중분류명         75
# 상권업종소분류코드       247
# 상권업종소분류명        247
# 표준산업분류코드        376
# 표준산업분류명         376
# 시도코드              1
# 시도명               1
# 시군구코드            47
# 시군구명             47
# 행정동코드           602
# 행정동명            577
# 법정동코드          1944
# 법정동명            694
# 지번코드         218465
# 대지구분코드            2
# 대지구분명             2
# 지번본번지          5001
# 지번부번지           809
# 지번주소         218465
# 도로명코드         21690
# 도로명           22192
# 건물본번지          3389
# 건물부번지           302
# 건물관리번호       218550
# 건물명           45584
# 도로명주소        219346
# 구우편번호          5339
# 신우편번호          6133
# 동정보               0
# 층정보             205
# 호정보               0
# 경도           228962
# 위도           228961
# dtype: int64

# %%
sorted(basedt['시군구명'].unique())
# Out:
# ['가평군',
#  '고양시 덕양구',
#  '고양시 일산동구',
#  '고양시 일산서구',
#  '과천시',
#  '광명시',
#  '광주시',
#  '구리시',
#  '군포시',
#  '김포시',
#  '남양주시',
#  '동두천시',
#  '부천시 소사구',
#  '부천시 오정구',
#  '부천시 원미구',
#  '성남시 분당구',
#  '성남시 수정구',
#  '성남시 중원구',
#  '수원시 권선구',
#  '수원시 영통구',
#  '수원시 장안구',
#  '수원시 팔달구',
#  '시흥시',
#  '안산시 단원구',
#  '안산시 상록구',
#  '안성시',
#  '안양시 동안구',
#  '안양시 만안구',
#  '양주시',
#  '양평군',
#  '여주시',
#  '연천군',
#  '오산시',
#  '용인시 기흥구',
#  '용인시 수지구',
#  '용인시 처인구',
#  '의왕시',
#  '의정부시',
#  '이천시',
#  '파주시',
#  '평택시',
#  '포천시',
#  '하남시',
#  '화성시 동탄구',
#  '화성시 만세구',
#  '화성시 병점구',
#  '화성시 효행구']

# %% [markdown]
# 1. 청년층 인구 비중이 높은 지역일수록 헬스장·PC방·카페의 인구 대비 업소 밀도가 높을 것이다. # 주 분석방향
# 2. 청년층 인구 비중과의 관계 정도는 헬스장·PC방·카페마다 다를 것이다. # 업종별 차이
# 3. 단순 업소 수와 청년층 인구 1만 명당 업소 수를 비교하면 지역 순위가 달라질 것이다. # 정규화
# 4. 청년층 비율이 비슷한 지역들 사이에서도 특정 업종 밀도가 유난히 높거나 낮은 지역이 존재할 것이다. # 이상치

# %%
age_df = pd.read_csv('../db/202606_연령별인구현황_월간.csv', encoding='cp949')
age_df
# Out:
#                          행정구역 2026년06월_계_총인구수 2026년06월_계_연령구간인구수  \
# 0           경기도  (4100000000)      13,761,783          3,463,598
# 1        경기도 수원시 (4111000000)       1,185,770            348,068
# 2    경기도 수원시 장안구 (4111100000)         269,984             72,708
# 3    경기도 수원시 권선구 (4111300000)         360,286            101,673
# 4    경기도 수원시 팔달구 (4111500000)         193,401             60,546
# 5    경기도 수원시 영통구 (4111700000)         362,099            113,141
# 6        경기도 성남시 (4113000000)         902,344            236,493
# 7    경기도 성남시 수정구 (4113100000)         234,639             63,702
# 8    경기도 성남시 중원구 (4113300000)         200,064             53,520
# 9    경기도 성남시 분당구 (4113500000)         467,641            119,271
# 10      경기도 의정부시 (4115000000)         461,917            113,202
# 11       경기도 안양시 (4117000000)         562,305            149,524
# 12   경기도 안양시 만안구 (4117100000)         233,711             61,567
# 13   경기도 안양시 동안구 (4117300000)         328,594             87,957
# 14       경기도 부천시 (4119000000)         755,453            186,986
# 15   경기도 부천시 원미구 (4119200000)         382,339             99,018
# 16   경기도 부천시 소사구 (4119400000)         224,202             51,795
# 17   경기도 부천시 오정구 (4119600000)         148,912             36,173
# 18       경기도 광명시 (4121000000)         303,666             78,529
# 19       경기도 평택시 (4122000000)         619,670            173,887
# 20      경기도 동두천시 (4125000000)          86,265             16,554
# 21       경기도 안산시 (4127000000)         609,240            162,566
# 22   경기도 안산시 상록구 (4127100000)         320,773             84,014
# 23   경기도 안산시 단원구 (4127300000)         288,467             78,552
# 24       경기도 고양시 (4128000000)       1,057,438            260,505
# 25   경기도 고양시 덕양구 (4128100000)         483,048            120,201
# 26  경기도 고양시 일산동구 (4128500000)         298,269             76,064
# 27  경기도 고양시 일산서구 (4128700000)         276,121             64,240
# 28       경기도 과천시 (4129000000)          80,832             20,609
# 29       경기도 구리시 (4131000000)         187,782             47,449
# 30      경기도 남양주시 (4136000000)         727,440            159,026
# 31       경기도 오산시 (4137000000)         253,590             69,780
# 32       경기도 시흥시 (4139000000)         514,831            130,329
# 33       경기도 군포시 (4141000000)         249,462             62,954
# 34       경기도 의왕시 (4143000000)         164,221             42,773
# 35       경기도 하남시 (4145000000)         327,495             81,069
# 36       경기도 용인시 (4146000000)       1,090,211            263,327
# 37   경기도 용인시 처인구 (4146100000)         286,391             69,751
# 38   경기도 용인시 기흥구 (4146300000)         434,590            105,276
# 39   경기도 용인시 수지구 (4146500000)         369,230             88,300
# 40       경기도 파주시 (4148000000)         533,387            128,854
# 41       경기도 이천시 (4150000000)         224,740             57,778
# 42       경기도 안성시 (4155000000)         198,785             45,725
# 43       경기도 김포시 (4157000000)         484,042            107,142
# 44       경기도 화성시 (4159000000)         998,746            274,125
# 45   경기도 화성시 만세구 (4159100000)         234,482             54,955
# 46   경기도 화성시 효행구 (4159300000)         160,481             42,602
# 47   경기도 화성시 병점구 (4159500000)         174,794             51,533
# 48   경기도 화성시 동탄구 (4159700000)         428,989            125,035
# 49       경기도 광주시 (4161000000)         399,111             89,150
# 50       경기도 양주시 (4163000000)         297,226             70,426
# 51       경기도 포천시 (4165000000)         140,468             27,704
# 52       경기도 여주시 (4167000000)         113,506             20,810
# 53       경기도 연천군 (4180000000)          42,977              8,573
# 54       경기도 가평군 (4182000000)          62,041             10,505
# 55       경기도 양평군 (4183000000)         126,822             19,176
#
#    2026년06월_계_20세 2026년06월_계_21세 2026년06월_계_22세 2026년06월_계_23세 2026년06월_계_24세  \
# 0         120,911        121,934        129,695        130,374        142,580
# 1          11,066         11,596         13,127         13,668         15,230
# 2           2,843          2,978          3,430          3,583          3,702
# 3           2,982          3,036          3,408          3,460          4,027
# 4           1,620          1,819          2,130          2,312          2,711
# 5           3,621          3,763          4,159          4,313          4,790
# 6           7,449          7,929          8,504          8,598          9,080
# 7           1,702          2,010          2,347          2,364          2,528
# 8           1,473          1,665          1,726          1,833          2,021
# 9           4,274          4,254          4,431          4,401          4,531
# 10          4,063          4,132          4,490          4,561          5,138
# 11          4,953          4,891          5,127          5,312          5,475
# 12          1,940          1,973          2,179          2,273          2,312
# 13          3,013          2,918          2,948          3,039          3,163
# 14          6,142          6,299          6,818          6,952          7,666
# 15          3,179          3,296          3,642          3,743          4,026
# 16          1,802          1,810          1,880          1,820          2,090
# 17          1,161          1,193          1,296          1,389          1,550
# 18          2,890          2,819          2,984          2,803          3,175
# 19          5,003          5,174          5,399          5,651          6,455
# 20            699            733            801            752            798
# 21          5,675          6,125          6,692          7,002          7,740
# 22          3,141          3,376          3,700          3,850          4,271
# 23          2,534          2,749          2,992          3,152          3,469
# 24          8,952          9,310          9,974          9,973         10,883
# 25          3,752          3,928          4,251          4,352          4,550
# 26          2,565          2,599          2,796          2,848          3,320
# 27          2,635          2,783          2,927          2,773          3,013
# 28            652            671            728            651            817
# 29          1,614          1,635          1,711          1,707          1,893
# 30          6,820          6,791          6,997          6,783          7,246
# 31          2,325          2,343          2,368          2,429          2,635
# 32          4,691          4,682          4,898          4,948          5,327
# 33          2,258          2,308          2,501          2,489          2,738
# 34          1,297          1,345          1,460          1,441          1,624
# 35          2,569          2,477          2,631          2,663          2,943
# 36         11,011         11,007         11,702         11,425         12,248
# 37          2,706          2,622          2,846          2,997          3,144
# 38          4,568          4,737          4,983          4,634          5,124
# 39          3,737          3,648          3,873          3,794          3,980
# 40          4,676          4,544          4,660          4,669          5,064
# 41          2,064          1,933          2,013          1,975          2,326
# 42          1,857          1,896          1,975          2,109          2,159
# 43          4,083          3,848          3,876          3,860          4,118
# 44          9,074          8,522          8,903          8,566          9,264
# 45          1,782          1,701          1,723          1,689          1,971
# 46          1,468          1,428          1,510          1,539          1,522
# 47          1,698          1,668          1,903          1,837          1,926
# 48          4,126          3,725          3,767          3,501          3,845
# 49          3,092          3,024          3,161          3,097          3,523
# 50          2,566          2,537          2,648          2,628          2,903
# 51            997            997          1,136          1,267          1,381
# 52            813            801            862            825            849
# 53            292            298            345            392            511
# 54            411            410            419            453            498
# 55            857            857            785            725            873
#
#    2026년06월_계_25세 2026년06월_계_26세  ... 2026년06월_여_30세 2026년06월_여_31세  \
# 0         166,585        173,296  ...         91,257         91,836
# 1          17,931         18,664  ...          9,774          9,670
# 2           4,293          4,237  ...          1,837          1,849
# 3           4,739          5,155  ...          3,012          2,952
# 4           3,226          3,403  ...          1,812          1,737
# 5           5,673          5,869  ...          3,113          3,132
# 6          10,843         11,805  ...          6,594          6,450
# 7           2,927          3,148  ...          1,722          1,653
# 8           2,417          2,810  ...          1,537          1,562
# 9           5,499          5,847  ...          3,335          3,235
# 10          5,806          6,023  ...          3,112          3,038
# 11          6,718          6,885  ...          4,085          4,259
# 12          2,814          2,994  ...          1,654          1,791
# 13          3,904          3,891  ...          2,431          2,468
# 14          9,155          9,439  ...          5,266          5,320
# 15          4,871          5,086  ...          2,818          2,890
# 16          2,401          2,402  ...          1,367          1,390
# 17          1,883          1,951  ...          1,081          1,040
# 18          3,433          3,669  ...          2,110          2,229
# 19          7,759          8,788  ...          4,368          4,389
# 20            923            914  ...            415            401
# 21          9,012          9,374  ...          4,315          4,197
# 22          4,931          4,971  ...          2,197          2,115
# 23          4,081          4,403  ...          2,118          2,082
# 24         12,849         13,537  ...          7,159          7,350
# 25          5,413          5,669  ...          3,319          3,464
# 26          3,966          4,198  ...          2,154          2,208
# 27          3,470          3,670  ...          1,686          1,678
# 28            840            881  ...            546            576
# 29          2,334          2,398  ...          1,377          1,309
# 30          8,117          8,073  ...          4,136          4,177
# 31          3,007          3,235  ...          1,660          1,722
# 32          6,071          6,396  ...          3,356          3,259
# 33          3,185          3,294  ...          1,729          1,652
# 34          1,928          1,970  ...          1,124          1,164
# 35          3,492          3,605  ...          2,260          2,235
# 36         13,699         13,480  ...          6,571          6,586
# 37          3,490          3,532  ...          1,679          1,702
# 38          5,845          5,714  ...          2,681          2,606
# 39          4,364          4,234  ...          2,211          2,278
# 40          5,943          6,086  ...          3,071          3,257
# 41          2,905          3,116  ...          1,367          1,360
# 42          2,461          2,358  ...          1,003          1,085
# 43          4,883          5,057  ...          2,769          2,783
# 44         11,107         12,073  ...          6,993          7,109
# 45          2,429          2,761  ...          1,297          1,216
# 46          1,746          1,693  ...          1,037          1,108
# 47          2,358          2,477  ...          1,211          1,237
# 48          4,574          5,142  ...          3,448          3,548
# 49          4,147          4,266  ...          2,211          2,320
# 50          3,329          3,321  ...          1,764          1,859
# 51          1,610          1,527  ...            721            648
# 52          1,043          1,042  ...            529            488
# 53            580            536  ...            170            201
# 54            565            582  ...            237            240
# 55            910            902  ...            465            503
#
#    2026년06월_여_32세 2026년06월_여_33세 2026년06월_여_34세 2026년06월_여_35세 2026년06월_여_36세  \
# 0          94,845         97,477         98,789         92,338         89,471
# 1           9,603          9,797          9,492          8,785          8,265
# 2           1,782          1,833          1,757          1,635          1,507
# 3           2,932          2,949          2,850          2,647          2,452
# 4           1,640          1,735          1,634          1,499          1,358
# 5           3,249          3,280          3,251          3,004          2,948
# 6           6,628          6,818          6,954          6,595          6,352
# 7           1,779          1,857          1,820          1,772          1,652
# 8           1,551          1,557          1,514          1,412          1,255
# 9           3,298          3,404          3,620          3,411          3,445
# 10          3,110          3,099          3,240          2,868          2,851
# 11          4,394          4,623          4,667          4,274          4,174
# 12          1,810          1,897          1,819          1,632          1,631
# 13          2,584          2,726          2,848          2,642          2,543
# 14          5,301          5,268          5,369          4,989          4,749
# 15          2,863          2,741          2,854          2,653          2,541
# 16          1,479          1,534          1,599          1,508          1,438
# 17            959            993            916            828            770
# 18          2,388          2,427          2,487          2,216          2,129
# 19          4,718          4,754          4,810          4,465          4,262
# 20            373            400            383            381            335
# 21          4,133          3,996          4,092          3,513          3,339
# 22          2,127          2,033          1,951          1,715          1,540
# 23          2,006          1,963          2,141          1,798          1,799
# 24          7,406          7,695          7,688          7,415          6,962
# 25          3,565          3,732          3,834          3,675          3,493
# 26          2,155          2,279          2,183          2,106          1,907
# 27          1,686          1,684          1,671          1,634          1,562
# 28            581            653            723            696            617
# 29          1,382          1,459          1,405          1,222          1,264
# 30          4,144          4,273          4,311          4,073          4,057
# 31          1,853          1,912          1,960          1,864          1,802
# 32          3,428          3,459          3,614          3,440          3,376
# 33          1,708          1,732          1,700          1,618          1,436
# 34          1,287          1,356          1,400          1,303          1,284
# 35          2,365          2,524          2,635          2,544          2,463
# 36          6,749          6,996          7,115          6,717          6,620
# 37          1,810          1,903          1,893          1,694          1,696
# 38          2,600          2,605          2,635          2,569          2,463
# 39          2,339          2,488          2,587          2,454          2,461
# 40          3,639          3,904          4,051          3,777          3,492
# 41          1,411          1,447          1,353          1,274          1,335
# 42          1,091          1,112          1,084          1,020            949
# 43          2,789          3,059          3,263          3,091          3,060
# 44          7,917          8,039          8,143          7,817          7,842
# 45          1,301          1,247          1,383          1,310          1,330
# 46          1,223          1,354          1,353          1,310          1,253
# 47          1,385          1,395          1,378          1,353          1,363
# 48          4,008          4,043          4,029          3,844          3,896
# 49          2,401          2,452          2,608          2,450          2,519
# 50          1,953          2,122          2,105          2,007          1,990
# 51            626            635            620            584            550
# 52            534            492            560            499            495
# 53            192            200            187            158            135
# 54            250            253            257            224            245
# 55            491            521            513            459            522
#
#    2026년06월_여_37세 2026년06월_여_38세 2026년06월_여_39세
# 0          89,068         87,333         88,354
# 1           8,015          7,677          7,731
# 2           1,496          1,429          1,474
# 3           2,298          2,319          2,247
# 4           1,264          1,160          1,215
# 5           2,957          2,769          2,795
# 6           6,262          6,206          6,170
# 7           1,596          1,578          1,497
# 8           1,260          1,234          1,213
# 9           3,406          3,394          3,460
# 10          2,705          2,751          2,690
# 11          4,077          3,946          3,813
# 12          1,531          1,489          1,392
# 13          2,546          2,457          2,421
# 14          4,648          4,626          4,584
# 15          2,512          2,436          2,521
# 16          1,384          1,466          1,368
# 17            752            724            695
# 18          2,084          2,070          2,052
# 19          4,169          4,082          4,151
# 20            338            361            383
# 21          3,208          3,088          3,067
# 22          1,534          1,507          1,486
# 23          1,674          1,581          1,581
# 24          6,871          6,632          6,660
# 25          3,403          3,274          3,273
# 26          1,979          1,860          1,861
# 27          1,489          1,498          1,526
# 28            703            665            723
# 29          1,114          1,115          1,077
# 30          4,053          4,103          4,273
# 31          1,750          1,788          1,871
# 32          3,416          3,323          3,379
# 33          1,474          1,385          1,359
# 34          1,208          1,119          1,166
# 35          2,576          2,473          2,565
# 36          6,766          6,615          6,912
# 37          1,695          1,619          1,673
# 38          2,470          2,557          2,523
# 39          2,601          2,439          2,716
# 40          3,665          3,629          3,686
# 41          1,441          1,292          1,386
# 42          1,022            996          1,036
# 43          3,275          3,356          3,475
# 44          7,959          7,732          7,823
# 45          1,378          1,375          1,404
# 46          1,219          1,141          1,155
# 47          1,348          1,335          1,339
# 48          4,014          3,881          3,925
# 49          2,477          2,486          2,521
# 50          1,898          1,888          1,885
# 51            551            518            518
# 52            507            510            495
# 53            157            165            149
# 54            203            228            237
# 55            476            508            517
#
# [56 rows x 67 columns]

# %%
age_df.head(2).T
# Out:
#                                     0                     1
# 행정구역                경기도  (4100000000)  경기도 수원시 (4111000000)
# 2026년06월_계_총인구수            13,761,783             1,185,770
# 2026년06월_계_연령구간인구수          3,463,598               348,068
# 2026년06월_계_20세                120,911                11,066
# 2026년06월_계_21세                121,934                11,596
# ...                               ...                   ...
# 2026년06월_여_35세                 92,338                 8,785
# 2026년06월_여_36세                 89,471                 8,265
# 2026년06월_여_37세                 89,068                 8,015
# 2026년06월_여_38세                 87,333                 7,677
# 2026년06월_여_39세                 88,354                 7,731
#
# [67 rows x 2 columns]

# %%
age_df.columns
# Out:
# Index(['행정구역', '2026년06월_계_총인구수', '2026년06월_계_연령구간인구수', '2026년06월_계_20세',
#        '2026년06월_계_21세', '2026년06월_계_22세', '2026년06월_계_23세', '2026년06월_계_24세',
#        '2026년06월_계_25세', '2026년06월_계_26세', '2026년06월_계_27세', '2026년06월_계_28세',
#        '2026년06월_계_29세', '2026년06월_계_30세', '2026년06월_계_31세', '2026년06월_계_32세',
#        '2026년06월_계_33세', '2026년06월_계_34세', '2026년06월_계_35세', '2026년06월_계_36세',
#        '2026년06월_계_37세', '2026년06월_계_38세', '2026년06월_계_39세', '2026년06월_남_총인구수',
#        '2026년06월_남_연령구간인구수', '2026년06월_남_20세', '2026년06월_남_21세',
#        '2026년06월_남_22세', '2026년06월_남_23세', '2026년06월_남_24세', '2026년06월_남_25세',
#        '2026년06월_남_26세', '2026년06월_남_27세', '2026년06월_남_28세', '2026년06월_남_29세',
#        '2026년06월_남_30세', '2026년06월_남_31세', '2026년06월_남_32세', '2026년06월_남_33세',
#        '2026년06월_남_34세', '2026년06월_남_35세', '2026년06월_남_36세', '2026년06월_남_37세',
#        '2026년06월_남_38세', '2026년06월_남_39세', '2026년06월_여_총인구수',
#        '2026년06월_여_연령구간인구수', '2026년06월_여_20세', '2026년06월_여_21세',
#        '2026년06월_여_22세', '2026년06월_여_23세', '2026년06월_여_24세', '2026년06월_여_25세',
#        '2026년06월_여_26세', '2026년06월_여_27세', '2026년06월_여_28세', '2026년06월_여_29세',
#        '2026년06월_여_30세', '2026년06월_여_31세', '2026년06월_여_32세', '2026년06월_여_33세',
#        '2026년06월_여_34세', '2026년06월_여_35세', '2026년06월_여_36세', '2026년06월_여_37세',
#        '2026년06월_여_38세', '2026년06월_여_39세'],
#       dtype='str')

# %%
age_df.shape
# Out:
# (56, 67)

# %%
age_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 67 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   행정구역                56 non-null     str
#  1   2026년06월_계_총인구수     56 non-null     str
#  2   2026년06월_계_연령구간인구수  56 non-null     str
#  3   2026년06월_계_20세      56 non-null     str
#  4   2026년06월_계_21세      56 non-null     str
#  5   2026년06월_계_22세      56 non-null     str
#  6   2026년06월_계_23세      56 non-null     str
#  7   2026년06월_계_24세      56 non-null     str
#  8   2026년06월_계_25세      56 non-null     str
#  9   2026년06월_계_26세      56 non-null     str
#  10  2026년06월_계_27세      56 non-null     str
#  11  2026년06월_계_28세      56 non-null     str
#  12  2026년06월_계_29세      56 non-null     str
#  13  2026년06월_계_30세      56 non-null     str
#  14  2026년06월_계_31세      56 non-null     str
#  15  2026년06월_계_32세      56 non-null     str
#  16  2026년06월_계_33세      56 non-null     str
#  17  2026년06월_계_34세      56 non-null     str
#  18  2026년06월_계_35세      56 non-null     str
#  19  2026년06월_계_36세      56 non-null     str
#  20  2026년06월_계_37세      56 non-null     str
#  21  2026년06월_계_38세      56 non-null     str
#  22  2026년06월_계_39세      56 non-null     str
#  23  2026년06월_남_총인구수     56 non-null     str
#  24  2026년06월_남_연령구간인구수  56 non-null     str
#  25  2026년06월_남_20세      56 non-null     str
#  26  2026년06월_남_21세      56 non-null     str
#  27  2026년06월_남_22세      56 non-null     str
#  28  2026년06월_남_23세      56 non-null     str
#  29  2026년06월_남_24세      56 non-null     str
#  30  2026년06월_남_25세      56 non-null     str
#  31  2026년06월_남_26세      56 non-null     str
#  32  2026년06월_남_27세      56 non-null     str
#  33  2026년06월_남_28세      56 non-null     str
#  34  2026년06월_남_29세      56 non-null     str
#  35  2026년06월_남_30세      56 non-null     str
#  36  2026년06월_남_31세      56 non-null     str
#  37  2026년06월_남_32세      56 non-null     str
#  38  2026년06월_남_33세      56 non-null     str
#  39  2026년06월_남_34세      56 non-null     str
#  40  2026년06월_남_35세      56 non-null     str
#  41  2026년06월_남_36세      56 non-null     str
#  42  2026년06월_남_37세      56 non-null     str
#  43  2026년06월_남_38세      56 non-null     str
#  44  2026년06월_남_39세      56 non-null     str
#  45  2026년06월_여_총인구수     56 non-null     str
#  46  2026년06월_여_연령구간인구수  56 non-null     str
#  47  2026년06월_여_20세      56 non-null     str
#  48  2026년06월_여_21세      56 non-null     str
#  49  2026년06월_여_22세      56 non-null     str
#  50  2026년06월_여_23세      56 non-null     str
#  51  2026년06월_여_24세      56 non-null     str
#  52  2026년06월_여_25세      56 non-null     str
#  53  2026년06월_여_26세      56 non-null     str
#  54  2026년06월_여_27세      56 non-null     str
#  55  2026년06월_여_28세      56 non-null     str
#  56  2026년06월_여_29세      56 non-null     str
#  57  2026년06월_여_30세      56 non-null     str
#  58  2026년06월_여_31세      56 non-null     str
#  59  2026년06월_여_32세      56 non-null     str
#  60  2026년06월_여_33세      56 non-null     str
#  61  2026년06월_여_34세      56 non-null     str
#  62  2026년06월_여_35세      56 non-null     str
#  63  2026년06월_여_36세      56 non-null     str
#  64  2026년06월_여_37세      56 non-null     str
#  65  2026년06월_여_38세      56 non-null     str
#  66  2026년06월_여_39세      56 non-null     str
# dtypes: str(67)
# memory usage: 29.4 KB

# %%
base_df['시군구명'].unique()[:10]
# Out:
# <StringArray>
# ['화성시 동탄구', '성남시 분당구',     '구리시', '수원시 팔달구', '용인시 처인구',     '이천시',    '남양주시',
#  '용인시 기흥구',     '하남시',     '파주시']
# Length: 10, dtype: str

# %%
age_df['행정구역'].head(10) #괄호및 코드 제거하는 전처리 필요
# Out:
# 0           경기도  (4100000000)
# 1        경기도 수원시 (4111000000)
# 2    경기도 수원시 장안구 (4111100000)
# 3    경기도 수원시 권선구 (4111300000)
# 4    경기도 수원시 팔달구 (4111500000)
# 5    경기도 수원시 영통구 (4111700000)
# 6        경기도 성남시 (4113000000)
# 7    경기도 성남시 수정구 (4113100000)
# 8    경기도 성남시 중원구 (4113300000)
# 9    경기도 성남시 분당구 (4113500000)
# Name: 행정구역, dtype: str

# %%
store_df = base_df.copy()
ageg_df = age_df.copy()

# %%
store_df.head(1).T
# Out:
#                                    0
# 상가업소번호          MA0106202201A0208596
# 상호명                     파리바게트동탄2기시범점
# 지점명                              NaN
# 상권업종대분류코드                         I2
# 상권업종대분류명                          음식
# 상권업종중분류코드                       I210
# 상권업종중분류명                       기타 간이
# 상권업종소분류코드                     I21001
# 상권업종소분류명                        빵/도넛
# 표준산업분류코드                      I56191
# 표준산업분류명                         제과점업
# 시도코드                              41
# 시도명                              경기도
# 시군구코드                          41597
# 시군구명                         화성시 동탄구
# 행정동코드                       41597540
# 행정동명                            동탄4동
# 법정동코드                     4159710500
# 법정동명                             청계동
# 지번코드             4159710500105140002
# 대지구분코드                             1
# 대지구분명                             대지
# 지번본번지                          514.0
# 지번부번지                            2.0
# 지번주소           경기도 화성시 동탄구 청계동 514-2
# 도로명코드                   415974852353
# 도로명              경기도 화성시 동탄구 동탄대로시범길
# 건물본번지                            253
# 건물부번지                            NaN
# 건물관리번호     4159013000200010000000002
# 건물명                              NaN
# 도로명주소        경기도 화성시 동탄구 동탄대로시범길 253
# 구우편번호                       445140.0
# 신우편번호                          18477
# 동정보                              NaN
# 층정보                              NaN
# 호정보                              NaN
# 경도                        127.102754
# 위도                         37.202218

# %%
ageg_df.head(1).T
# Out:
#                                     0
# 행정구역                경기도  (4100000000)
# 2026년06월_계_총인구수            13,761,783
# 2026년06월_계_연령구간인구수          3,463,598
# 2026년06월_계_20세                120,911
# 2026년06월_계_21세                121,934
# ...                               ...
# 2026년06월_여_35세                 92,338
# 2026년06월_여_36세                 89,471
# 2026년06월_여_37세                 89,068
# 2026년06월_여_38세                 87,333
# 2026년06월_여_39세                 88,354
#
# [67 rows x 1 columns]

# %%
ageg_df['행정구역'].str.replace('경기도','')
# Out:
# 0               (4100000000)
# 1           수원시 (4111000000)
# 2       수원시 장안구 (4111100000)
# 3       수원시 권선구 (4111300000)
# 4       수원시 팔달구 (4111500000)
# 5       수원시 영통구 (4111700000)
# 6           성남시 (4113000000)
# 7       성남시 수정구 (4113100000)
# 8       성남시 중원구 (4113300000)
# 9       성남시 분당구 (4113500000)
# 10         의정부시 (4115000000)
# 11          안양시 (4117000000)
# 12      안양시 만안구 (4117100000)
# 13      안양시 동안구 (4117300000)
# 14          부천시 (4119000000)
# 15      부천시 원미구 (4119200000)
# 16      부천시 소사구 (4119400000)
# 17      부천시 오정구 (4119600000)
# 18          광명시 (4121000000)
# 19          평택시 (4122000000)
# 20         동두천시 (4125000000)
# 21          안산시 (4127000000)
# 22      안산시 상록구 (4127100000)
# 23      안산시 단원구 (4127300000)
# 24          고양시 (4128000000)
# 25      고양시 덕양구 (4128100000)
# 26     고양시 일산동구 (4128500000)
# 27     고양시 일산서구 (4128700000)
# 28          과천시 (4129000000)
# 29          구리시 (4131000000)
# 30         남양주시 (4136000000)
# 31          오산시 (4137000000)
# 32          시흥시 (4139000000)
# 33          군포시 (4141000000)
# 34          의왕시 (4143000000)
# 35          하남시 (4145000000)
# 36          용인시 (4146000000)
# 37      용인시 처인구 (4146100000)
# 38      용인시 기흥구 (4146300000)
# 39      용인시 수지구 (4146500000)
# 40          파주시 (4148000000)
# 41          이천시 (4150000000)
# 42          안성시 (4155000000)
# 43          김포시 (4157000000)
# 44          화성시 (4159000000)
# 45      화성시 만세구 (4159100000)
# 46      화성시 효행구 (4159300000)
# 47      화성시 병점구 (4159500000)
# 48      화성시 동탄구 (4159700000)
# 49          광주시 (4161000000)
# 50          양주시 (4163000000)
# 51          포천시 (4165000000)
# 52          여주시 (4167000000)
# 53          연천군 (4180000000)
# 54          가평군 (4182000000)
# 55          양평군 (4183000000)
# Name: 행정구역, dtype: str

# %%
ageg_df['행정구역'].str.replace(r'\([^)]*\)', '',regex=True)
# Out:
# 0             경기도
# 1          경기도 수원시
# 2      경기도 수원시 장안구
# 3      경기도 수원시 권선구
# 4      경기도 수원시 팔달구
# 5      경기도 수원시 영통구
# 6          경기도 성남시
# 7      경기도 성남시 수정구
# 8      경기도 성남시 중원구
# 9      경기도 성남시 분당구
# 10        경기도 의정부시
# 11         경기도 안양시
# 12     경기도 안양시 만안구
# 13     경기도 안양시 동안구
# 14         경기도 부천시
# 15     경기도 부천시 원미구
# 16     경기도 부천시 소사구
# 17     경기도 부천시 오정구
# 18         경기도 광명시
# 19         경기도 평택시
# 20        경기도 동두천시
# 21         경기도 안산시
# 22     경기도 안산시 상록구
# 23     경기도 안산시 단원구
# 24         경기도 고양시
# 25     경기도 고양시 덕양구
# 26    경기도 고양시 일산동구
# 27    경기도 고양시 일산서구
# 28         경기도 과천시
# 29         경기도 구리시
# 30        경기도 남양주시
# 31         경기도 오산시
# 32         경기도 시흥시
# 33         경기도 군포시
# 34         경기도 의왕시
# 35         경기도 하남시
# 36         경기도 용인시
# 37     경기도 용인시 처인구
# 38     경기도 용인시 기흥구
# 39     경기도 용인시 수지구
# 40         경기도 파주시
# 41         경기도 이천시
# 42         경기도 안성시
# 43         경기도 김포시
# 44         경기도 화성시
# 45     경기도 화성시 만세구
# 46     경기도 화성시 효행구
# 47     경기도 화성시 병점구
# 48     경기도 화성시 동탄구
# 49         경기도 광주시
# 50         경기도 양주시
# 51         경기도 포천시
# 52         경기도 여주시
# 53         경기도 연천군
# 54         경기도 가평군
# 55         경기도 양평군
# Name: 행정구역, dtype: str

# %%
ageg_df['region_name'] = (
    ageg_df['행정구역']
    .str.replace('경기도','',regex=False)
    .str.replace(r'\([^)]*\)', '',regex=True)
    .str.strip() #공백때문에 strip 추가
)

# %%
ageg_df[['행정구역','region_name']]
# Out:
#                          행정구역 region_name
# 0           경기도  (4100000000)
# 1        경기도 수원시 (4111000000)         수원시
# 2    경기도 수원시 장안구 (4111100000)     수원시 장안구
# 3    경기도 수원시 권선구 (4111300000)     수원시 권선구
# 4    경기도 수원시 팔달구 (4111500000)     수원시 팔달구
# 5    경기도 수원시 영통구 (4111700000)     수원시 영통구
# 6        경기도 성남시 (4113000000)         성남시
# 7    경기도 성남시 수정구 (4113100000)     성남시 수정구
# 8    경기도 성남시 중원구 (4113300000)     성남시 중원구
# 9    경기도 성남시 분당구 (4113500000)     성남시 분당구
# 10      경기도 의정부시 (4115000000)        의정부시
# 11       경기도 안양시 (4117000000)         안양시
# 12   경기도 안양시 만안구 (4117100000)     안양시 만안구
# 13   경기도 안양시 동안구 (4117300000)     안양시 동안구
# 14       경기도 부천시 (4119000000)         부천시
# 15   경기도 부천시 원미구 (4119200000)     부천시 원미구
# 16   경기도 부천시 소사구 (4119400000)     부천시 소사구
# 17   경기도 부천시 오정구 (4119600000)     부천시 오정구
# 18       경기도 광명시 (4121000000)         광명시
# 19       경기도 평택시 (4122000000)         평택시
# 20      경기도 동두천시 (4125000000)        동두천시
# 21       경기도 안산시 (4127000000)         안산시
# 22   경기도 안산시 상록구 (4127100000)     안산시 상록구
# 23   경기도 안산시 단원구 (4127300000)     안산시 단원구
# 24       경기도 고양시 (4128000000)         고양시
# 25   경기도 고양시 덕양구 (4128100000)     고양시 덕양구
# 26  경기도 고양시 일산동구 (4128500000)    고양시 일산동구
# 27  경기도 고양시 일산서구 (4128700000)    고양시 일산서구
# 28       경기도 과천시 (4129000000)         과천시
# 29       경기도 구리시 (4131000000)         구리시
# 30      경기도 남양주시 (4136000000)        남양주시
# 31       경기도 오산시 (4137000000)         오산시
# 32       경기도 시흥시 (4139000000)         시흥시
# 33       경기도 군포시 (4141000000)         군포시
# 34       경기도 의왕시 (4143000000)         의왕시
# 35       경기도 하남시 (4145000000)         하남시
# 36       경기도 용인시 (4146000000)         용인시
# 37   경기도 용인시 처인구 (4146100000)     용인시 처인구
# 38   경기도 용인시 기흥구 (4146300000)     용인시 기흥구
# 39   경기도 용인시 수지구 (4146500000)     용인시 수지구
# 40       경기도 파주시 (4148000000)         파주시
# 41       경기도 이천시 (4150000000)         이천시
# 42       경기도 안성시 (4155000000)         안성시
# 43       경기도 김포시 (4157000000)         김포시
# 44       경기도 화성시 (4159000000)         화성시
# 45   경기도 화성시 만세구 (4159100000)     화성시 만세구
# 46   경기도 화성시 효행구 (4159300000)     화성시 효행구
# 47   경기도 화성시 병점구 (4159500000)     화성시 병점구
# 48   경기도 화성시 동탄구 (4159700000)     화성시 동탄구
# 49       경기도 광주시 (4161000000)         광주시
# 50       경기도 양주시 (4163000000)         양주시
# 51       경기도 포천시 (4165000000)         포천시
# 52       경기도 여주시 (4167000000)         여주시
# 53       경기도 연천군 (4180000000)         연천군
# 54       경기도 가평군 (4182000000)         가평군
# 55       경기도 양평군 (4183000000)         양평군

# %%
sorted(store_df['시군구명'].unique())
# Out:
# ['가평군',
#  '고양시 덕양구',
#  '고양시 일산동구',
#  '고양시 일산서구',
#  '과천시',
#  '광명시',
#  '광주시',
#  '구리시',
#  '군포시',
#  '김포시',
#  '남양주시',
#  '동두천시',
#  '부천시 소사구',
#  '부천시 오정구',
#  '부천시 원미구',
#  '성남시 분당구',
#  '성남시 수정구',
#  '성남시 중원구',
#  '수원시 권선구',
#  '수원시 영통구',
#  '수원시 장안구',
#  '수원시 팔달구',
#  '시흥시',
#  '안산시 단원구',
#  '안산시 상록구',
#  '안성시',
#  '안양시 동안구',
#  '안양시 만안구',
#  '양주시',
#  '양평군',
#  '여주시',
#  '연천군',
#  '오산시',
#  '용인시 기흥구',
#  '용인시 수지구',
#  '용인시 처인구',
#  '의왕시',
#  '의정부시',
#  '이천시',
#  '파주시',
#  '평택시',
#  '포천시',
#  '하남시',
#  '화성시 동탄구',
#  '화성시 만세구',
#  '화성시 병점구',
#  '화성시 효행구']

# %%
region_names = ageg_df['region_name'].unique() #소계만 추리기

del_regions = []

for region in region_names:
    sub_region = any(
        name.startswith(region + ' ')
        for name in region_names
        if name != region
    )
    
    if sub_region:
        del_regions.append(region)

# %%
sorted(del_regions) #strip 추가안했을땐 실행안되고 추가후에 실행됨
# Out:
# ['고양시', '부천시', '성남시', '수원시', '안산시', '안양시', '용인시', '화성시']

# %%
ageg_df = ageg_df[ #상위 시(소계) 삭제 코드
    ~ageg_df['region_name'].isin(del_regions)
].copy()

# %%
ageg_df = ageg_df[ #경기도(총계) 삭제 코드
    ageg_df['region_name'].str.strip() != ''
].copy()

# %%
ageg_df[['행정구역','region_name']]
# Out:
#                          행정구역 region_name
# 2    경기도 수원시 장안구 (4111100000)     수원시 장안구
# 3    경기도 수원시 권선구 (4111300000)     수원시 권선구
# 4    경기도 수원시 팔달구 (4111500000)     수원시 팔달구
# 5    경기도 수원시 영통구 (4111700000)     수원시 영통구
# 7    경기도 성남시 수정구 (4113100000)     성남시 수정구
# 8    경기도 성남시 중원구 (4113300000)     성남시 중원구
# 9    경기도 성남시 분당구 (4113500000)     성남시 분당구
# 10      경기도 의정부시 (4115000000)        의정부시
# 12   경기도 안양시 만안구 (4117100000)     안양시 만안구
# 13   경기도 안양시 동안구 (4117300000)     안양시 동안구
# 15   경기도 부천시 원미구 (4119200000)     부천시 원미구
# 16   경기도 부천시 소사구 (4119400000)     부천시 소사구
# 17   경기도 부천시 오정구 (4119600000)     부천시 오정구
# 18       경기도 광명시 (4121000000)         광명시
# 19       경기도 평택시 (4122000000)         평택시
# 20      경기도 동두천시 (4125000000)        동두천시
# 22   경기도 안산시 상록구 (4127100000)     안산시 상록구
# 23   경기도 안산시 단원구 (4127300000)     안산시 단원구
# 25   경기도 고양시 덕양구 (4128100000)     고양시 덕양구
# 26  경기도 고양시 일산동구 (4128500000)    고양시 일산동구
# 27  경기도 고양시 일산서구 (4128700000)    고양시 일산서구
# 28       경기도 과천시 (4129000000)         과천시
# 29       경기도 구리시 (4131000000)         구리시
# 30      경기도 남양주시 (4136000000)        남양주시
# 31       경기도 오산시 (4137000000)         오산시
# 32       경기도 시흥시 (4139000000)         시흥시
# 33       경기도 군포시 (4141000000)         군포시
# 34       경기도 의왕시 (4143000000)         의왕시
# 35       경기도 하남시 (4145000000)         하남시
# 37   경기도 용인시 처인구 (4146100000)     용인시 처인구
# 38   경기도 용인시 기흥구 (4146300000)     용인시 기흥구
# 39   경기도 용인시 수지구 (4146500000)     용인시 수지구
# 40       경기도 파주시 (4148000000)         파주시
# 41       경기도 이천시 (4150000000)         이천시
# 42       경기도 안성시 (4155000000)         안성시
# 43       경기도 김포시 (4157000000)         김포시
# 45   경기도 화성시 만세구 (4159100000)     화성시 만세구
# 46   경기도 화성시 효행구 (4159300000)     화성시 효행구
# 47   경기도 화성시 병점구 (4159500000)     화성시 병점구
# 48   경기도 화성시 동탄구 (4159700000)     화성시 동탄구
# 49       경기도 광주시 (4161000000)         광주시
# 50       경기도 양주시 (4163000000)         양주시
# 51       경기도 포천시 (4165000000)         포천시
# 52       경기도 여주시 (4167000000)         여주시
# 53       경기도 연천군 (4180000000)         연천군
# 54       경기도 가평군 (4182000000)         가평군
# 55       경기도 양평군 (4183000000)         양평군

# %%
base_regions = set(store_df['시군구명'].unique()) #전처리 확인
age_regions = set(ageg_df['region_name'].unique())

print('상권dt 지역 수', len(base_regions))
print('인구db 지역 수', len(age_regions))
print('공통 지역 수', len(base_regions & age_regions))
print('상권에만 있는 지역', sorted(base_regions - age_regions))
print('인구에만 있는 지역', sorted(age_regions - base_regions))
# Out:
# 상권dt 지역 수 47
# 인구db 지역 수 47
# 공통 지역 수 47
# 상권에만 있는 지역 []
# 인구에만 있는 지역 []

# %%
age_cols = [
    f'2026년06월_계_{age}세'
    for age in range(20, 40)
]

# %%
ageg_df[age_cols] = (
    ageg_df[age_cols].replace(',','', regex=True).astype(int) #연령대별 인구값 문자 -> 숫자로 변환
)

# %%
ageg_df['age_sum'] = ageg_df[age_cols].sum(axis=1)

# %%
print(ageg_df['age_sum'])
# Out:
# 2      72708
# 3     101673
# 4      60546
# 5     113141
# 7      63702
# 8      53520
# 9     119271
# 10    113202
# 12     61567
# 13     87957
# 15     99018
# 16     51795
# 17     36173
# 18     78529
# 19    173887
# 20     16554
# 22     84014
# 23     78552
# 25    120201
# 26     76064
# 27     64240
# 28     20609
# 29     47449
# 30    159026
# 31     69780
# 32    130329
# 33     62954
# 34     42773
# 35     81069
# 37     69751
# 38    105276
# 39     88300
# 40    128854
# 41     57778
# 42     45725
# 43    107142
# 45     54955
# 46     42602
# 47     51533
# 48    125035
# 49     89150
# 50     70426
# 51     27704
# 52     20810
# 53      8573
# 54     10505
# 55     19176
# Name: age_sum, dtype: int64

# %%
ageg_df['2026년06월_계_연령구간인구수'] = (
    ageg_df['2026년06월_계_연령구간인구수'].str.replace(',','',regex=False).astype(int) #csv 데이터값 문자 -> 숫자로 변환
)

# %%
(ageg_df['age_sum'] # 20~39세 합계값과 연령구간인구수 컬럼값 비교
    == ageg_df['2026년06월_계_연령구간인구수']
).all()
#연령구간인구수 컬럼값을 청년층인구수로 사용해도 된다는 근거
# Out:
# np.True_

# %%
store_df.head(1).T
# Out:
#                                    0
# 상가업소번호          MA0106202201A0208596
# 상호명                     파리바게트동탄2기시범점
# 지점명                              NaN
# 상권업종대분류코드                         I2
# 상권업종대분류명                          음식
# 상권업종중분류코드                       I210
# 상권업종중분류명                       기타 간이
# 상권업종소분류코드                     I21001
# 상권업종소분류명                        빵/도넛
# 표준산업분류코드                      I56191
# 표준산업분류명                         제과점업
# 시도코드                              41
# 시도명                              경기도
# 시군구코드                          41597
# 시군구명                         화성시 동탄구
# 행정동코드                       41597540
# 행정동명                            동탄4동
# 법정동코드                     4159710500
# 법정동명                             청계동
# 지번코드             4159710500105140002
# 대지구분코드                             1
# 대지구분명                             대지
# 지번본번지                          514.0
# 지번부번지                            2.0
# 지번주소           경기도 화성시 동탄구 청계동 514-2
# 도로명코드                   415974852353
# 도로명              경기도 화성시 동탄구 동탄대로시범길
# 건물본번지                            253
# 건물부번지                            NaN
# 건물관리번호     4159013000200010000000002
# 건물명                              NaN
# 도로명주소        경기도 화성시 동탄구 동탄대로시범길 253
# 구우편번호                       445140.0
# 신우편번호                          18477
# 동정보                              NaN
# 층정보                              NaN
# 호정보                              NaN
# 경도                        127.102754
# 위도                         37.202218

# %%
store_db_cols = [
    '상가업소번호',
    '상호명',
    '상권업종대분류코드',
    '상권업종대분류명',
    '상권업종중분류코드',
    '상권업종중분류명',
    '상권업종소분류코드',
    '상권업종소분류명',
    '표준산업분류코드',
    '표준산업분류명',
    '시도코드',
    '시도명',
    '시군구명',
    '행정동코드',
    '행정동명',
    '법정동코드',
    '법정동명',
    '지번주소',
    '도로명주소',
    '신우편번호',
    '경도',
    '위도'    
]

store_rename_df = store_df[store_db_cols].copy()

# %%
store_rename_df = store_rename_df.rename(columns={
     '상가업소번호': 'store_id',
        '상호명': 'store_name',
        '상권업종대분류코드': 'category_large_id',
        '상권업종대분류명': 'category_large_name',
        '상권업종중분류코드': 'category_medium_id',
        '상권업종중분류명': 'category_medium_name',
        '상권업종소분류코드': 'category_small_id',
        '상권업종소분류명': 'category_small_name',
        '표준산업분류코드': 'industry_code',
        '표준산업분류명': 'industry_name',
        '시도코드': 'province_code',
        '시도명': 'province_name',
        '시군구명': 'region_name',
        '행정동코드': 'admin_dong_code',
        '행정동명': 'admin_dong_name',
        '법정동코드': 'legal_dong_code',
        '법정동명': 'legal_dong_name',
        '지번주소': 'lot_address',
        '도로명주소': 'road_address',
        '신우편번호': 'postal_code',
        '경도': 'longitude',
        '위도': 'latitude'   
})

# %%
year_db_cols = [
    'region_name',
    '2026년06월_계_총인구수',
    '2026년06월_계_연령구간인구수'
]

year_rename_df = ageg_df[year_db_cols].copy()

# %%
year_rename_df = year_rename_df.rename(columns={
        '2026년06월_계_총인구수': 'total_population',
        '2026년06월_계_연령구간인구수': 'year_population'
})

# %%
store_rename_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 672680 entries, 0 to 672679
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   store_id              672680 non-null  str
#  1   store_name            672680 non-null  str
#  2   category_large_id     672680 non-null  str
#  3   category_large_name   672680 non-null  str
#  4   category_medium_id    672680 non-null  str
#  5   category_medium_name  672680 non-null  str
#  6   category_small_id     672680 non-null  str
#  7   category_small_name   672680 non-null  str
#  8   industry_code         672463 non-null  str
#  9   industry_name         672463 non-null  str
#  10  province_code         672680 non-null  int64
#  11  province_name         672680 non-null  str
#  12  region_name           672680 non-null  str
#  13  admin_dong_code       672680 non-null  int64
#  14  admin_dong_name       672680 non-null  str
#  15  legal_dong_code       672680 non-null  int64
#  16  legal_dong_name       670792 non-null  str
#  17  lot_address           672680 non-null  str
#  18  road_address          672680 non-null  str
#  19  postal_code           672680 non-null  int64
#  20  longitude             672680 non-null  float64
#  21  latitude              672680 non-null  float64
# dtypes: float64(2), int64(4), str(16)
# memory usage: 112.9 MB

# %%
year_rename_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 47 entries, 2 to 55
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   region_name       47 non-null     str
#  1   total_population  47 non-null     int64
#  2   year_population   47 non-null     int64
# dtypes: int64(2), str(1)
# memory usage: 1.5 KB

# %%
year_rename_df['total_population'] = (
    year_rename_df['total_population'].str.replace(',','',regex = False).astype(int))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[168], line 2
#       1 year_rename_df['total_population'] = (
# ----> 2     year_rename_df['total_population'].str.replace(',','',regex = False).astype(int))
#
# File /opt/anaconda3/envs/study/lib/python3.12/site-packages/pandas/core/generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# File /opt/anaconda3/envs/study/lib/python3.12/site-packages/pandas/core/accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# --> 230 return self._accessor(obj)
#
# File /opt/anaconda3/envs/study/lib/python3.12/site-packages/pandas/core/strings/accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File /opt/anaconda3/envs/study/lib/python3.12/site-packages/pandas/core/strings/accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError(
#     249         f"Can only use .str accessor with string values, not {inferred_dtype}"
#     250     )
#     251 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values, not integer

# %%
print('store중복값', store_rename_df.duplicated().sum())
print('year중복값', year_rename_df.duplicated().sum())
# Out:
# store중복값 0
# year중복값 0

# %%
pip install sqlalchemy pymysql
# Out:
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/envs/study/lib/python3.12/site-packages (2.0.52)
# Requirement already satisfied: pymysql in /opt/anaconda3/envs/study/lib/python3.12/site-packages (1.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from sqlalchemy) (4.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

engine = create_engine(
    'mysql+pymysql://han0210:test1234@localhost:3306/minipjt'
)

# %%
year_rename_df.to_sql(
    name = 'population',
    con = engine,
    if_exists = 'append',
    index = False
)
# Out:
# 47

# %%
store_rename_df.to_sql(
    name = 'stores',
    con = engine,
    if_exists = 'append',
    index = False,
    chunksize=10000
)
# Out:
# 672680

# %%
query = """
SELECT 
    p.region_name,
    p.young_population / p.total_population * 100 AS '청년비율',
    COUNT(*) / p.young_population * 10000 AS '청년 1만명당 업소수'
FROM stores AS s
JOIN population AS p
ON s.region_name = p.region_name
WHERE s.category_small_name IN (
    '헬스장', 'PC방', '카페'
)
GROUP BY p.region_name, p.young_population, p.total_population;
"""

df = pd.read_sql(query, engine)

# %%
df.columns
# Out:
# Index(['region_name', '청년비율', '업소밀도'], dtype='str')

# %%
df[['청년비율','청년 1만명당 업소수']].corr()
# Out:
#                  청년비율  청년 1만명당 업소수
# 청년비율         1.000000    -0.664158
# 청년 1만명당 업소수 -0.664158     1.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(
    df['청년비율'],
    df['청년 1만명당 업소수']
)

plt.xlabel('청년비율')
plt.ylabel('청년 1만명당 업소수')
plt.show()
# Out:
# /opt/anaconda3/envs/study/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/study/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/study/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/study/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/study/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/study/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/study/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/study/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/study/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/study/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#해석: 강한 음의 관계, 청년비율이 높은 지역일수록 오히려 청년 1만명당 업소 밀도가 낮아지는 경향

# %%
query = """
SELECT s.category_small_name AS '업종', 
    p.region_name,
    p.young_population / p.total_population * 100 AS '청년비율',
    COUNT(*) / p.young_population * 10000 AS '청년 1만명당 업소수'
FROM stores AS s
JOIN population AS p
ON s.region_name = p.region_name
WHERE s.category_small_name IN (
    '헬스장', 'PC방', '카페'
)
GROUP BY s.category_small_name, p.region_name, p.young_population, p.total_population;
"""

df1 = pd.read_sql(query, engine)

# %%
#업종별 상관계수
df1.groupby('업종')[
    ['청년비율','청년 1만명당 업소수']
].corr()
# Out:
#                      청년비율  청년 1만명당 업소수
# 업종
# PC방 청년비율         1.000000    -0.275262
#     청년 1만명당 업소수 -0.275262     1.000000
# 카페  청년비율         1.000000    -0.681402
#     청년 1만명당 업소수 -0.681402     1.000000
# 헬스장 청년비율         1.000000     0.220641
#     청년 1만명당 업소수  0.220641     1.000000

# %%
#결과해석 
# pc방: 청년 비율이 높다고해서 pc방 밀도가 높진 않으며 오히려 약간 낮은 경향을 보인다.
# 카페: 청년 비율이 높을수록 청년 1만명당 카페 밀도는 낮게 나타났다.
# 헬스장: 청년 비율이 높을수록 밀도가 증가하는 경향은 있으나 영향은 크지 않다.

# %%
query = """
SELECT s.category_small_name AS category, 
    p.region_name,
    ROUND(
    p.young_population / p.total_population * 100, 2
    ) AS young_ratio,
    COUNT(*) AS store_count,
    ROUND(
        COUNT(*) / p.young_population * 10000, 2
    ) AS young_store_density
FROM stores AS s
JOIN population AS p
ON s.region_name = p.region_name
WHERE s.category_small_name IN (
    '헬스장', 'PC방', '카페'
)
GROUP BY s.category_small_name, p.region_name, p.young_population, p.total_population;
"""

df2 = pd.read_sql(query, engine)

# %%
cafe_df = df3[df3['category'] == '카페']

cafe_df[
    (cafe_df['young_ratio'] >= 20) &
    (cafe_df['young_ratio'] <= 25)
].sort_values(
    'young_store_density',
    ascending=False
).head(10)
# Out:
#    category region_name  young_ratio  store_count  young_store_density
# 91       카페     화성시 만세구        23.44          587               106.81
# 72       카페         안성시        23.00          470               102.79
# 82       카페     용인시 처인구        24.36          696                99.78
# 56       카페         김포시        22.13          936                87.36
# 86       카페         파주시        24.16         1099                85.29
# 53       카페         광주시        22.34          701                78.63
# 57       카페        남양주시        21.86         1198                75.33
# 84       카페        의정부시        24.51          798                70.49
# 89       카페         하남시        24.75          567                69.94
# 75       카페         양주시        23.69          484                68.72

# %%
df2.sort_values(
    'store_count',
    ascending=False
).head(10)
# Out:
#    category region_name  young_ratio  store_count  young_store_density
# 87       카페         평택시        28.06         1283                73.78
# 57       카페        남양주시        21.86         1198                75.33
# 86       카페         파주시        24.16         1099                85.29
# 62       카페     성남시 분당구        25.50         1098                92.06
# 56       카페         김포시        22.13          936                87.36
# 69       카페         시흥시        25.31          915                70.21
# 61       카페     부천시 원미구        25.90          892                90.08
# 90       카페     화성시 동탄구        29.15          839                67.10
# 66       카페     수원시 영통구        31.25          835                73.80
# 84       카페        의정부시        24.51          798                70.49

# %%
df2.sort_values(
    'young_store_density',
    ascending=False
).head(10)
# Out:
#    category region_name  young_ratio  store_count  young_store_density
# 47       카페         가평군        16.93          295               280.82
# 76       카페         양평군        15.12          440               229.45
# 88       카페         포천시        19.72          441               159.18
# 77       카페         여주시        18.33          313               150.41
# 78       카페         연천군        19.95          121               141.14
# 68       카페     수원시 팔달구        31.31          752               124.20
# 58       카페        동두천시        19.19          179               108.13
# 91       카페     화성시 만세구        23.44          587               106.81
# 49       카페    고양시 일산동구        25.50          782               102.81
# 72       카페         안성시        23.00          470               102.79

# %%
#해석 
#단순 업소 수 기준 순위와 청년 기준 업소 밀도 순위는 차이를 보였으며, 
#인구 규모가 아닌 청년층 규모를 기준으로 정규화할 경우 지역별 업종 공급 수준 평가 결과가 달라지는 것을 확인하였다.

# %%
query = """
SELECT s.category_small_name AS category, 
    p.region_name,
    ROUND(
    p.young_population / p.total_population * 100, 2
    ) AS young_ratio,
    COUNT(*) AS store_count,
    ROUND(
        COUNT(*) / p.young_population * 10000, 2
    ) AS young_store_density
FROM stores AS s
JOIN population AS p
ON s.region_name = p.region_name
WHERE s.category_small_name IN (
    '헬스장', 'PC방', '카페'
)
GROUP BY s.category_small_name, p.region_name, p.young_population, p.total_population;
"""

df3 = pd.read_sql(query, engine)

# %%
df3[['young_ratio','young_store_density']].describe()
# Out:
#        young_ratio  young_store_density
# count   141.000000           141.000000
# mean     24.721064            35.059645
# std       3.292467            45.530139
# min      15.120000             1.940000
# 25%      23.270000             6.820000
# 50%      25.270000            10.470000
# 75%      26.750000            66.940000
# max      31.310000           280.820000

# %%
cafe_df = df3[df3['category'] == '카페']

cafe_df[
    (cafe_df['young_ratio'] >= 20) &
    (cafe_df['young_ratio'] <= 25)
].sort_values(
    'young_store_density',
    ascending=False
).head(10)
# Out:
#    category region_name  young_ratio  store_count  young_store_density
# 91       카페     화성시 만세구        23.44          587               106.81
# 72       카페         안성시        23.00          470               102.79
# 82       카페     용인시 처인구        24.36          696                99.78
# 56       카페         김포시        22.13          936                87.36
# 86       카페         파주시        24.16         1099                85.29
# 53       카페         광주시        22.34          701                78.63
# 57       카페        남양주시        21.86         1198                75.33
# 84       카페        의정부시        24.51          798                70.49
# 89       카페         하남시        24.75          567                69.94
# 75       카페         양주시        23.69          484                68.72

# %%
pc_df = df3[df3['category'] == 'PC방']

pc_df[
    (pc_df['young_ratio'] >= 20) &
    (pc_df['young_ratio'] <= 25)
].sort_values(
    'young_store_density',
    ascending=False
).head(10)
# Out:
#    category region_name  young_ratio  store_count  young_store_density
# 44      PC방     화성시 만세구        23.44           51                 9.28
# 35      PC방     용인시 처인구        24.36           45                 6.45
# 13      PC방     부천시 오정구        24.29           23                 6.36
# 37      PC방        의정부시        24.51           69                 6.10
# 9       PC방         김포시        22.13           65                 6.07
# 25      PC방         안성시        23.00           25                 5.47
# 12      PC방     부천시 소사구        23.10           28                 5.41
# 28      PC방         양주시        23.69           33                 4.69
# 39      PC방         파주시        24.16           58                 4.50
# 10      PC방        남양주시        21.86           68                 4.28

# %%
gym_df = df3[df3['category'] == '헬스장']

gym_df[
    (gym_df['young_ratio'] >= 20) &
    (gym_df['young_ratio'] <= 25)
].sort_values(
    'young_store_density',
    ascending=False
).head(10)
# Out:
#     category region_name  young_ratio  store_count  young_store_density
# 128      헬스장     용인시 수지구        23.91          122                13.82
# 103      헬스장         김포시        22.13          135                12.60
# 131      헬스장        의정부시        24.51          142                12.54
# 127      헬스장     용인시 기흥구        24.22          130                12.35
# 136      헬스장         하남시        24.75           99                12.21
# 97       헬스장    고양시 일산서구        23.27           76                11.83
# 138      헬스장     화성시 만세구        23.44           64                11.65
# 119      헬스장         안성시        23.00           49                10.72
# 95       헬스장     고양시 덕양구        24.88          127                10.57
# 104      헬스장        남양주시        21.86          166                10.44

# %%
#해석 
#청년층 비율이 비슷한 지역이라도 업종별 공급 수준에는 차이가 발생하였다. 
#즉 단순히 청년 인구 규모만으로 업종 분포가 결정되는 것이 아니라, 지역별 상권 특성이나 소비 환경 등의 요인이 영향을 미칠 가능성이 있다.

# %%
plt.rcParams['font.family'] = 'AppleGothic'

# %%
plt.figure(figsize=(8,5))

plt.scatter(
    df3['young_ratio'],
    df3['young_store_density']
)

plt.xlabel('청년비율(%)')
plt.ylabel('청년 1만명 당 업소 수')
plt.title('청년 비율과 업소밀도 관계')

plt.grid(alpha=0.3)
plt.show()

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from seaborn) (2.5.1)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=9 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/study/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns

# %%
sim_df = df3[
    (df3['young_ratio'] >= 20) &
    (df3['young_ratio'] <= 25)
] 

cafe_df = sim_df[
    sim_df['category'] == '카페'
]

plt.figure(figsize=(6,4))

sns.scatterplot(
    data=cafe_df,
    x = 'young_ratio',
    y = 'young_store_density',
)

plt.xlabel('청년비율(%)')
plt.ylabel('청년 1만명 당 업소 수')
plt.title('유사 청년비율 유사 지역의 카페 업소 밀도')

plt.show()

# %%
gym_df = sim_df[
    sim_df['category'] == '헬스장'
]

plt.figure(figsize=(6,4))

sns.scatterplot(
    data=gym_df,
    x = 'young_ratio',
    y = 'young_store_density',
)

plt.xlabel('청년비율(%)')
plt.ylabel('청년 1만명 당 업소 수')
plt.title('유사 청년비율 유사 지역의 헬스장 업소 밀도')

plt.show()

# %%
pc_df = sim_df[
    sim_df['category'] == 'PC방'
]

plt.figure(figsize=(6,4))

sns.scatterplot(
    data=pc_df,
    x = 'young_ratio',
    y = 'young_store_density',
)

plt.xlabel('청년비율(%)')
plt.ylabel('청년 1만명 당 업소 수')
plt.title('유사 청년비율 유사 지역의 PC방 업소 밀도')

plt.show()
